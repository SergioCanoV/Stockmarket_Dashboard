# %%
import requests
import pandas as pd
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import seaborn as sns

params = {
  'access_key': '39a2aca43db62a20ca2f68884462e5ae',
  'date_from': '2023-01-01T00:00:00+0000',
  'date_to': '2023-12-24T00:00:00+0000',
  'limit': '950'
}

api_result1 = requests.get('http://api.marketstack.com/v1/tickers/aapl/eod', params)
api_result2 = requests.get('http://api.marketstack.com/v1/tickers/amzn/eod', params)
api_result3 = requests.get('http://api.marketstack.com/v1/tickers/msft/eod', params)
api_result4 = requests.get('http://api.marketstack.com/v1/tickers/nvda/eod', params)
api_result5 = requests.get('http://api.marketstack.com/v1/tickers/lyft/eod', params)
api_result6 = requests.get('http://api.marketstack.com/v1/tickers/wbd/eod', params)
api_result7 = requests.get('http://api.marketstack.com/v1/tickers/tsla/eod', params)
api_result8 = requests.get('http://api.marketstack.com/v1/tickers/para/eod', params)
api_result9 = requests.get('http://api.marketstack.com/v1/tickers/meta/eod', params)
api_result10 = requests.get('http://api.marketstack.com/v1/tickers/intc/eod', params)


api_response1 = api_result1.json()
api_response2 = api_result2.json()
api_response3 = api_result3.json()
api_response4 = api_result4.json()
api_response5 = api_result5.json()
api_response6 = api_result6.json()
api_response7 = api_result7.json()
api_response8 = api_result8.json()
api_response9 = api_result9.json()
api_response10 = api_result10.json()

print(api_response1)
print(api_response2)
print(api_response3)
print(api_response4)
print(api_response5)
print(api_response6)
print(api_response7)
print(api_response8)
print(api_response9)
print(api_response10)
# Out:
# {'error': {'code': 'usage_limit_reached', 'message': 'Your monthly usage limit has been reached. Please upgrade your Subscription Plan.'}}
# {'error': {'code': 'usage_limit_reached', 'message': 'Your monthly usage limit has been reached. Please upgrade your Subscription Plan.'}}
# {'error': {'code': 'usage_limit_reached', 'message': 'Your monthly usage limit has been reached. Please upgrade your Subscription Plan.'}}
# {'error': {'code': 'usage_limit_reached', 'message': 'Your monthly usage limit has been reached. Please upgrade your Subscription Plan.'}}
# {'error': {'code': 'usage_limit_reached', 'message': 'Your monthly usage limit has been reached. Please upgrade your Subscription Plan.'}}
# {'error': {'code': 'usage_limit_reached', 'message': 'Your monthly usage limit has been reached. Please upgrade your Subscription Plan.'}}
# {'error': {'code': 'usage_limit_reached', 'message': 'Your monthly usage limit has been reached. Please upgrade your Subscription Plan.'}}
# {'error': {'code': 'usage_limit_reached', 'message': 'Your monthly usage limit has been reached. Please upgrade your Subscription Plan.'}}
# {'error': {'code': 'usage_limit_reached', 'message': 'Your monthly usage limit has been reached. Please upgrade your Subscription Plan.'}}
# {'error': {'code': 'usage_limit_reached', 'message': 'Your monthly usage limit has been reached. Please upgrade your Subscription Plan.'}}

# %%
pd.DataFrame(api_response1['data'])
# Out:
#           name symbol country  has_intraday  has_eod
# 0    Apple Inc   AAPL    None         False     True  \
# 1    Apple Inc   AAPL    None         False     True
# 2    Apple Inc   AAPL    None         False     True
# 3    Apple Inc   AAPL    None         False     True
# 4    Apple Inc   AAPL    None         False     True
# ..         ...    ...     ...           ...      ...
# 230  Apple Inc   AAPL    None         False     True
# 231  Apple Inc   AAPL    None         False     True
# 232  Apple Inc   AAPL    None         False     True
# 233  Apple Inc   AAPL    None         False     True
# 234  Apple Inc   AAPL    None         False     True
#
#                                                    eod
# 0    {'open': 193.63, 'high': 195.0, 'low': 193.59,...
# 1    {'open': 194.45, 'high': 194.76, 'low': 192.12...
# 2    {'open': 190.21, 'high': 194.4, 'low': 190.21,...
# 3    {'open': 189.98, 'high': 190.01, 'low': 187.46...
# 4    {'open': 190.33, 'high': 191.56, 'low': 189.23...
# ..                                                 ...
# 230  {'open': 130.47, 'high': 133.41, 'low': 129.89...
# 231  {'open': 126.01, 'high': 130.29, 'low': 124.89...
# 232  {'open': 127.13, 'high': 127.77, 'low': 124.76...
# 233  {'open': 126.89, 'high': 128.66, 'low': 125.08...
# 234  {'open': 130.28, 'high': 130.9, 'low': 124.17,...
#
# [235 rows x 6 columns]

# %%
pd.DataFrame(api_response2['data'])
# Out:
#                name symbol country  has_intraday  has_eod
# 0    Amazon.com Inc   AMZN    None         False     True  \
# 1    Amazon.com Inc   AMZN    None         False     True
# 2    Amazon.com Inc   AMZN    None         False     True
# 3    Amazon.com Inc   AMZN    None         False     True
# 4    Amazon.com Inc   AMZN    None         False     True
# ..              ...    ...     ...           ...      ...
# 230  Amazon.com Inc   AMZN    None         False     True
# 231  Amazon.com Inc   AMZN    None         False     True
# 232  Amazon.com Inc   AMZN    None         False     True
# 233  Amazon.com Inc   AMZN    None         False     True
# 234  Amazon.com Inc   AMZN    None         False     True
#
#                                                    eod
# 0    {'open': 146.15, 'high': 147.915, 'low': 145.3...
# 1    {'open': 147.58, 'high': 147.85, 'low': 144.28...
# 2    {'open': 143.55, 'high': 148.57, 'low': 143.13...
# 3    {'open': 145.25, 'high': 145.35, 'low': 142.81...
# 4    {'open': 146.0, 'high': 147.25, 'low': 145.55,...
# ..                                                 ...
# 230  {'open': 87.46, 'high': 89.48, 'low': 87.08, '...
# 231  {'open': 83.03, 'high': 86.4, 'low': 81.43, 'c...
# 232  {'open': 85.33, 'high': 85.42, 'low': 83.07, '...
# 233  {'open': 86.55, 'high': 86.98, 'low': 83.36, '...
# 234  {'open': 85.46, 'high': 86.96, 'low': 84.205, ...
#
# [235 rows x 6 columns]

# %%
list_companies = [api_response1,api_response2,api_response3,api_response4,api_response5,api_response6,api_response7,api_response8,api_response9,api_response10]

def api_response(api_company):
  return pd.DataFrame(api_company['data'])

temp_list = []
for i in range(0,len(list_companies)):
  # t = 'df'+str(i)
  temp_list.append(api_response(list_companies[i]))
df_temp = pd.concat(temp_list)
df_temp2 = df_temp['eod'].apply(pd.Series)

# %%
df_temp2['avg'] = (df_temp2.high+df_temp2.low)/2
df_temp2[['date2','time']] = df_temp2['date'].str.split('T', expand=True)
df_temp2.drop('date',axis=1,inplace=True)
df_temp2.rename(columns={'date2':'date'},inplace=True)
df_temp2['date'] = pd.to_datetime(df_temp2['date'])

# %% [raw]
# df_temp = df_temp.reset_index()
# df_temp2 = df_temp2.reset_index()
# df2 = df_temp.join(df_temp2[['open','high', 'low','close','volume','adj_high','adj_low','adj_close','adj_open','adj_volume','split_factor','dividend','exchange','date']],on='index').set_index('index')
# df2['avg'] = (df2.high+df2.low)/2
# df2.drop(axis=1,labels='eod',inplace=True)
#
# df2[['date2','time']] = df2['date'].str.split('T', expand=True)
#
# df2.drop('date',axis=1,inplace=True)
# df2.rename(columns={'date2':'date'},inplace=True)
#
# df2['date'] = pd.to_datetime(df2['date'])

# %%
df_temp2.head()
# Out:
#      open    high     low   close      volume  adj_high   adj_low  adj_close
# 0  193.63  195.00  193.59  194.27  44260847.0    195.00  193.5900     194.27  \
# 1  194.45  194.76  192.12  192.32  39500106.0    194.76  192.1100     192.32
# 2  190.21  194.40  190.21  193.42  63350286.0    194.40  190.1800     193.42
# 3  189.98  190.01  187.46  189.43  41666588.0    190.05  187.4511     189.43
# 4  190.33  191.56  189.23  191.24  45679300.0    191.56  189.2300     191.24
#
#    adj_open  adj_volume  split_factor  dividend symbol exchange      avg
# 0    193.63  47338824.0           1.0       0.0   AAPL     XNAS  194.295  \
# 1    194.45  40895115.0           1.0       0.0   AAPL     XNAS  193.440
# 2    190.21  66628398.0           1.0       0.0   AAPL     XNAS  192.305
# 3    189.98  43389519.0           1.0       0.0   AAPL     XNAS  188.735
# 4    190.33  45704823.0           1.0       0.0   AAPL     XNAS  190.395
#
#         date           time
# 0 2023-12-07  00:00:00+0000
# 1 2023-12-06  00:00:00+0000
# 2 2023-12-05  00:00:00+0000
# 3 2023-12-04  00:00:00+0000
# 4 2023-12-01  00:00:00+0000

# %%
df_temp2.loc[df_temp2.date=='2023-11-07']
# Out:
#       open    high     low   close       volume  adj_high  adj_low  adj_close
# 21  179.18  182.44  178.98  181.82   69660972.0    182.44  178.970     181.82  \
# 21  140.55  143.37  140.50  142.71   53498500.0    143.37  140.500     142.71
# 21  359.40  362.46  357.63  360.53   25807100.0    362.46  357.630     360.53
# 21  457.19  462.18  451.58  459.55   34244300.0    462.18  451.575     459.55
# 21   10.59   10.87   10.32   10.83   16928646.0     10.87   10.320      10.83
# 21   11.45   11.71   11.35   11.61   23350000.0     11.71   11.350      11.61
# 21  219.98  223.12  215.72  222.18  116900130.0    223.12  215.720     222.18
# 21   12.62   12.95   12.50   12.84   12591100.0     12.95   12.500      12.84
# 21  317.06  321.00  315.12  318.82   13613815.0    321.00  315.120     318.82
# 21   38.24   38.90   37.98   38.77   32052041.0     38.90   37.980      38.77
#
#     adj_open   adj_volume  split_factor  dividend symbol exchange      avg
# 21    179.18   70529966.0           1.0       0.0   AAPL     XNAS  180.710  \
# 21    140.55   53553537.0           1.0       0.0   AMZN     XNAS  141.935
# 21    359.40   25833931.0           1.0       0.0   MSFT     XNAS  360.045
# 21    457.19   34316547.0           1.0       0.0   NVDA     XNAS  456.880
# 21     10.59   16993182.0           1.0       0.0   LYFT     XNAS   10.595
# 21     11.45   24405125.0           1.0       0.0    WBD     XNAS   11.530
# 21    219.98  116900130.0           1.0       0.0   TSLA     XNAS  219.420
# 21     12.62   12593401.0           1.0       0.0   PARA     OOTC   12.725
# 21    317.06   14055614.0           1.0       0.0   META     ARCX  318.060
# 21     38.24   32052041.0           1.0       0.0   INTC     XNAS   38.440
#
#          date           time
# 21 2023-11-07  00:00:00+0000
# 21 2023-11-07  00:00:00+0000
# 21 2023-11-07  00:00:00+0000
# 21 2023-11-07  00:00:00+0000
# 21 2023-11-07  00:00:00+0000
# 21 2023-11-07  00:00:00+0000
# 21 2023-11-07  00:00:00+0000
# 21 2023-11-07  00:00:00+0000
# 21 2023-11-07  00:00:00+0000
# 21 2023-11-07  00:00:00+0000

# %%
from datetime import datetime,timedelta

# %%
pd.to_datetime(datetime.now().date() - timedelta(days=14))
# Out:
# Timestamp('2023-11-23 00:00:00')

# %%
temp = df_temp2.loc[:,['date','symbol','avg','high','low','open','close','volume']].sort_values('date',ascending=False)
temp.loc[temp.date >= pd.to_datetime(datetime.now().date() - timedelta(days=14))]
# Out:
#          date symbol        avg     high       low    open   close      volume
# 0  2023-12-07   AAPL  194.29500  195.000  193.5900  193.63  194.27  44260847.0
# 0  2023-12-07   AMZN  146.62750  147.915  145.3400  146.15  146.88  44424386.0
# 0  2023-12-07   INTC   41.80755   42.435   41.1801   41.75   42.15  27628834.0
# 0  2023-12-07   META  323.00500  328.240  317.7700  317.77  326.59  15774634.0
# 0  2023-12-07   PARA   15.14750   15.335   14.9600   15.25   15.03   9515572.0
# ..        ...    ...        ...      ...       ...     ...     ...         ...
# 9  2023-11-24    WBD   10.78000   10.950   10.6100   10.62   10.85   6790000.0
# 9  2023-11-24   NVDA  483.33000  489.210  477.4500  484.70  477.76  29464500.0
# 9  2023-11-24   LYFT   10.12750   10.325    9.9300   10.27   10.27   6774300.0
# 9  2023-11-24   TSLA  235.54000  238.750  232.3300  233.75  235.45  65125203.0
# 9  2023-11-24   AAPL  190.07500  190.900  189.2500  190.87  189.97  24048300.0
#
# [100 rows x 8 columns]

# %%
temp = df_temp2.loc[:,['date','symbol','avg','high','low','open','close','volume']].sort_values('date',ascending=False)
temp.loc[(temp.date >= pd.to_datetime(datetime.now().date() - timedelta(days=14))) & (temp.symbol == 'AAPL')].set_index('date')
# Out:
#            symbol        avg      high     low    open   close      volume
# date
# 2023-12-07   AAPL  194.29500  195.0000  193.59  193.63  194.27  44260847.0
# 2023-12-06   AAPL  193.44000  194.7600  192.12  194.45  192.32  39500106.0
# 2023-12-05   AAPL  192.30500  194.4000  190.21  190.21  193.42  63350286.0
# 2023-12-04   AAPL  188.73500  190.0100  187.46  189.98  189.43  41666588.0
# 2023-12-01   AAPL  190.39500  191.5600  189.23  190.33  191.24  45679300.0
# 2023-11-30   AAPL  189.25500  190.3200  188.19  189.84  189.95  45197107.0
# 2023-11-29   AAPL  190.53000  192.0900  188.97  190.90  189.37  36346229.0
# 2023-11-28   AAPL  190.24000  191.0800  189.40  189.78  190.40  36588319.0
# 2023-11-27   AAPL  189.78495  190.6699  188.90  189.92  189.79  37224665.0
# 2023-11-24   AAPL  190.07500  190.9000  189.25  190.87  189.97  24048300.0

# %%
temp = df_temp2.loc[:,['date','symbol','avg','high','low','open','close','volume']].sort_values('date',ascending=False)
temp = temp.loc[(temp.date >= pd.to_datetime(datetime.now().date() - timedelta(days=14))) & (temp.symbol == 'AAPL')]

# %%
temp_obj = temp.select_dtypes(['object'])
temp[temp_obj.columns] = temp_obj.apply(lambda x: x.str.strip())

# %%
print(temp)
# Out:
#         date symbol        avg      high     low    open   close      volume
# 0 2023-12-07   AAPL  194.29500  195.0000  193.59  193.63  194.27  44260847.0
# 1 2023-12-06   AAPL  193.44000  194.7600  192.12  194.45  192.32  39500106.0
# 2 2023-12-05   AAPL  192.30500  194.4000  190.21  190.21  193.42  63350286.0
# 3 2023-12-04   AAPL  188.73500  190.0100  187.46  189.98  189.43  41666588.0
# 4 2023-12-01   AAPL  190.39500  191.5600  189.23  190.33  191.24  45679300.0
# 5 2023-11-30   AAPL  189.25500  190.3200  188.19  189.84  189.95  45197107.0
# 6 2023-11-29   AAPL  190.53000  192.0900  188.97  190.90  189.37  36346229.0
# 7 2023-11-28   AAPL  190.24000  191.0800  189.40  189.78  190.40  36588319.0
# 8 2023-11-27   AAPL  189.78495  190.6699  188.90  189.92  189.79  37224665.0
# 9 2023-11-24   AAPL  190.07500  190.9000  189.25  190.87  189.97  24048300.0

# %%
tableRender('AAPL')
# Out:
#            symbol        avg      high     low    open   close      volume
# 2023-12-07   AAPL  194.29500  195.0000  193.59  193.63  194.27  44260847.0
# 2023-12-06   AAPL  193.44000  194.7600  192.12  194.45  192.32  39500106.0
# 2023-12-05   AAPL  192.30500  194.4000  190.21  190.21  193.42  63350286.0
# 2023-12-04   AAPL  188.73500  190.0100  187.46  189.98  189.43  41666588.0
# 2023-12-01   AAPL  190.39500  191.5600  189.23  190.33  191.24  45679300.0
# 2023-11-30   AAPL  189.25500  190.3200  188.19  189.84  189.95  45197107.0
# 2023-11-29   AAPL  190.53000  192.0900  188.97  190.90  189.37  36346229.0
# 2023-11-28   AAPL  190.24000  191.0800  189.40  189.78  190.40  36588319.0
# 2023-11-27   AAPL  189.78495  190.6699  188.90  189.92  189.79  37224665.0
# 2023-11-24   AAPL  190.07500  190.9000  189.25  190.87  189.97  24048300.0

# %%
def tableRender(company):
    temp = df_temp2.loc[:,['date','symbol','avg','high','low','open','close','volume']].sort_values('date',ascending=False)
    temp = temp.loc[(temp.date >= pd.to_datetime(datetime.now().date() - timedelta(days=14))) & (temp.symbol == company)].set_index('date')
    temp.index.name = None
    return temp

# %%
def candlestick_graph(company):
    fig = go.Figure(data=[go.Candlestick(x=df_temp2['date'],
                    open=df_temp2.loc[df_temp2.symbol==company].open,
                    high=df_temp2.loc[df_temp2.symbol==company].high,
                    low=df_temp2.loc[df_temp2.symbol==company].low,
                    close=df_temp2.loc[df_temp2.symbol==company].close)])
    fig.show()

# %%
candlestick_graph('AAPL')
# Out:
# <div>                            <div id="dd83df87-d52c-419a-b3a1-0e2f9b3a642d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd83df87-d52c-419a-b3a1-0e2f9b3a642d")) {                    Plotly.newPlot(                        "dd83df87-d52c-419a-b3a1-0e2f9b3a642d",                        [{"close":[181.82,179.23,176.65,177.57,173.97,170.77,170.29,168.22,166.89,171.1,173.44,173.0,172.88,175.46,175.84,177.15,178.72,178.85,180.71,179.8,178.39,178.99,177.49,174.91,173.66,172.4,173.75,171.21,170.69,170.43,171.96,176.08,174.79,173.93,175.49,179.07,177.97,175.01,175.74,174.21,176.3,179.36,178.18,177.56,182.91,189.7,189.46,187.87,187.65,184.12,180.19,178.61,176.38,181.12,177.23,175.84,174.49,174.0,176.57,177.45,179.46,177.79,177.97,178.19,179.8,178.85,181.99,191.17,192.58,195.61,196.45,195.83,193.22,194.5,193.62,192.75,191.94,193.13,195.1,193.73,193.99,190.69,190.54,189.77,188.08,188.61,190.68,191.81,191.33,192.46,193.97,189.59,189.25,188.06,185.27,186.68,187.0,183.96,185.01,184.92,186.01,183.95,183.31,183.79,180.96,180.57,177.82,179.21,179.58,180.95,180.09,177.25,177.3,175.43,172.99,171.84,171.56,174.2,175.16,175.05,172.69,172.07,172.07,172.57,173.75,173.56,171.77,173.5,173.57,165.79,167.45,168.54,169.59,169.68,168.41,163.76,163.77,165.33,165.02,166.65,167.63,166.47,165.23,165.21,165.56,160.1,160.8,162.03,164.66,163.76,165.63,166.17,164.9,162.36,160.77,157.65,158.28,160.25,158.93,157.83,159.28,157.4,155.0,155.85,152.99,152.59,150.47,148.5,150.59,152.87,151.6,153.83,151.03,145.91,145.31,147.41,147.92,146.71,149.4,148.91,148.48,152.55,153.71,155.33,153.2,153.85,151.01,150.87,151.92,154.65,151.73,154.5,150.82,145.43,144.29,143.0,145.93,143.96,141.86,142.53,141.11,137.87,135.27,135.21,135.94,134.76,133.41,133.49,130.73,130.15,129.62,125.02,126.36,125.07],"high":[182.44,179.43,176.82,177.78,174.23,170.9,171.17,168.96,171.3775,173.06,173.67,174.01,175.42,177.84,177.57,178.42,179.075,181.93,182.34,179.85,179.72,179.05,177.99,175.4411,174.21,173.63,174.3,173.07,172.026,173.04,175.055,176.96,177.08,176.3,179.695,179.63,179.38,176.5,176.1,177.3,180.12,180.3,180.239,178.21,188.735,189.98,189.92,189.12,187.79,184.9,180.585,179.15,181.104,181.55,177.6778,176.13,175.1,177.5054,178.53,179.47,179.69,178.62,180.75,180.93,180.27,183.13,187.38,192.37,195.18,196.73,196.49,196.63,197.2,195.64,194.44,194.91,194.97,196.47,198.22,194.33,194.32,191.18,191.19,191.7,189.28,189.99,192.67,192.018,192.98,193.88,194.48,190.07,189.9,188.3899,188.05,187.56,187.05,185.41,186.1,186.99,186.52,184.39,184.15,183.89,182.23,180.84,181.21,180.12,184.95,181.78,180.12,179.35,178.99,175.77,173.9,172.42,173.38,174.71,176.39,175.24,172.93,173.14,173.21,174.06,174.59,174.03,173.54,173.85,174.3,167.04,170.92,170.35,170.45,169.85,168.56,165.28,166.3,165.6,166.45,167.87,168.16,167.41,165.39,166.32,165.8,162.06,162.36,162.03,164.9584,165.05,166.83,166.29,165.0,162.47,161.04,158.1277,160.77,160.34,161.55,162.14,159.4,157.81,156.74,156.42,153.245,153.4,153.14,150.94,154.5312,153.47,154.0299,156.295,151.11,146.71,147.2285,149.075,149.17,147.19,150.34,149.95,151.3,153.0,156.33,155.5,153.77,154.26,151.34,154.33,154.58,155.23,153.1,157.38,151.18,146.61,144.34,145.55,147.23,144.25,142.43,143.16,143.32,138.02,136.25,138.61,137.29,134.92,134.26,133.51,131.26,133.41,130.29,127.77,128.66,130.9],"low":[178.98,176.21,173.35,175.46,170.13,167.9,168.87,166.83,165.67,170.65,171.46,169.94,172.64,175.19,175.11,174.8,176.51,178.14,179.04,177.6,177.95,175.805,173.18,172.68,170.98,170.82,171.0,170.34,167.62,169.05,171.66,174.155,174.05,173.86,175.4,177.13,176.44,173.82,173.58,173.98,174.82,177.34,177.79,173.54,181.47,187.61,188.28,187.48,184.74,179.5,178.545,175.82,176.02,178.325,176.25,173.735,171.96,173.48,176.5,177.0517,177.305,176.55,177.601,177.01,177.58,177.36,1 ...

# %%
stock_graph('AAPL')

# %%
def stock_graph(company):
  plt.figure(figsize=(14,5))
  sns.set_style("ticks")
  sns.barplot(data=df2.loc[df2.symbol == company,['date','open','high','low','close','adj_close','volume']],x="date",y='volume',color='firebrick')
#   sns.barplot(data=df2.loc[df2.symbol == company,['date','open','high','low','close','adj_close','volume']],x="date",y='open',color='firebrick')
  sns.despine()
  plt.title("The Stock Price of " + company,size='x-large',color='blue')
